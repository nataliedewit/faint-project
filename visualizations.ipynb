# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


fig, ax1 = plt.subplots(1, 1, figsize=(10,4))
sns.histplot(df, bins = 35, stat = 'probability', label="Distribution of the VVR score")
ax1.set_title('Distribution of the VVR scores', fontsize= 18)
ax1.set_ylabel('Probability', fontsize= 16)
ax1.set_xlabel('VVR score', fontsize= 14)
plt.legend([],[], frameon=False)

# %%
hist = pd.read_csv("histograms.csv", sep = ",")

a = hist['val acc']
b = hist['val loss']
c = hist['auc']


fig, (ax1, ax2,ax3) = plt.subplots(1, 3, figsize=(15,5))
ax1.set_title('Distribution of validation accuracy', fontsize= 18)
ax1.set_ylabel('Probability', fontsize= 16)
ax2.set_ylabel('Probability', fontsize= 16)
ax3.set_ylabel('Probability', fontsize= 16)
ax2.set_title('Distribution of validation loss', fontsize= 18)
ax3.set_title('Distribution of AUC', fontsize= 18)
sns.histplot(a, ax=ax1, bins = 8, stat = 'probability')
sns.histplot(b, ax = ax2, bins = 10, stat = 'probability')
sns.histplot(c, ax = ax3, bins = 10, stat = 'probability')
# Out:
# 36
# <AxesSubplot:title={'center':'Distribution of AUC'}, xlabel='auc', ylabel='Probability'>

# %%
p = pd.read_csv("lr.csv", sep = ",")
p = p[:18]
g = pd.read_csv("dropout.csv", sep = ",")
k = pd.read_csv("epochs.csv", sep = ",")
k = k[:18]
a = g['val acc 1']
b = g['val acc 25']
c = g['val acc 50']
d = p['val acc 1']
e = p['val acc 01']
f = l['val acc 8']
g = l['val acc 16']
h = l['val acc 32']
i = k['50 epochs']
j = k['100 epochs']

fig, (ax1, ax2,ax3,ax4) = plt.subplots(1, 4, figsize=(15,5))
ax1.set_title('Impact units on accuracy', fontsize= 13)
ax2.set_title('Impact dropout on accuracy', fontsize= 13)
ax3.set_title('Impact learning rate on accuracy', fontsize= 13)
ax4.set_title('Impact epochs on accuracy', fontsize= 13)
ax1.set_ylabel('Validation accuracy', fontsize= 16)
ax1.boxplot([f,g,h], labels=['8 units', '16 units', "32 units"])
ax2.boxplot([a,b,c], labels=['0.1 dropout', '0.25 dropout', "0.5 dropout"])
ax3.boxplot([d,e], labels=['learning rate 0.001', 'learning rate 0.0001'])
ax4.boxplot([i,j], labels=['50 epochs', '100 epochs'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2037c6ff490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2037c6ffb50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2037c6ff130>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2037c709250>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2037c7095b0>,
# ...
#  'means': []}

# %%
pp = pd.read_csv("lrloss.csv", sep = ",")
gg = pd.read_csv("dropoutloss.csv", sep = ",")
kk = pd.read_csv("epochsloss.csv", sep = ",")
ll = pd.read_csv("untisloss.csv", sep = ",")
a = gg['loss 0.1']
b = gg['loss 0.25']
c = gg['loss 0.5']
d = pp['loss 1']
e = pp['loss 01']
f = ll['loss 8']
g = ll['loss 16']
h = ll['loss 32']
i = kk['50 loss']
j = kk['100 loss']

fig, (ax1, ax2,ax3,ax4) = plt.subplots(1, 4, figsize=(15,5))
ax1.set_title('Impact units on validation loss', fontsize= 13)
ax2.set_title('Impact dropout on validation loss', fontsize= 13)
ax3.set_title('Impact learning rate on validation loss', fontsize= 13)
ax4.set_title('Impact epochs on validation loss', fontsize= 13)
ax1.set_ylabel('Validation loss', fontsize= 16)
ax1.boxplot([f,g,h], labels=['8 units', '16 units', "32 units"])
ax2.boxplot([a,b,c], labels=['0.1 dropout', '0.25 dropout', "0.5 dropout"])
ax3.boxplot([d,e], labels=['learning rate 0.001', 'learning rate 0.0001'])
ax4.boxplot([i,j], labels=['50 epochs', '100 epochs'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20375d19d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20375d33490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20375d19a30>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x20375d33b50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x20375d33eb0>,
# ...
#  'means': []}

# %%
ppp = pd.read_csv("lrauc.csv", sep = ",")
ggg = pd.read_csv("dropoutauc.csv", sep = ",")
kkk = pd.read_csv("epochsauc.csv", sep = ",")
lll = pd.read_csv("unitsauc.csv", sep = ",")
a = ggg['auc 0.1']
b = ggg['auc 0.25']
c = ggg['auc 0.5']
d = ppp['auc 1']
e = ppp['auc 01']
f = lll['auc 8']
g = lll['auc 16 ']
h = lll['auc 32']
i = kkk['auc 50']
j = kkk['auc 100']

fig, (ax1, ax2,ax3,ax4) = plt.subplots(1, 4, figsize=(15,5))
ax1.set_title('Impact units on AUC', fontsize= 13)
ax2.set_title('Impact dropout on AUC', fontsize= 13)
ax3.set_title('Impact learning rate on AUC', fontsize= 13)
ax4.set_title('Impact epochs on AUC', fontsize= 13)
ax1.set_ylabel('AUC', fontsize= 16)
ax1.boxplot([f,g,h], labels=['8 units', '16 units', "32 units"])
ax2.boxplot([a,b,c], labels=['0.1 dropout', '0.25 dropout', "0.5 dropout"])
ax3.boxplot([d,e], labels=['learning rate 0.001', 'learning rate 0.0001'])
ax4.boxplot([i,j], labels=['50 epochs', '100 epochs'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2036b8e20d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2036b8e2700>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2036b783df0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2036b981460>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2036b981970>,
# ...
#  'means': []}
